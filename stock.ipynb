# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (0.2.12)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (37.0.2)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.28.0)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.24.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: pycparser in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the 'c:\Users\hetsu\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (5.13.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages (from plotly) (8.2.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\hetsu\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the 'c:\Users\hetsu\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd

#Data Source

import yfinance as yf

#Data Visualization
import plotly.graph_objs as go

# %%
stock = input("Please enter stock ticker: ")

data = yf.download(tickers=stock, period='1d', interval='1m')

fig = go.Figure()

fig.add_trace(go.Candlestick(x=data.index,
                            open=data['Open'],
                            high=data['High'],
                            low=data['Low'],
                            close=data['Close'], name='market data'))

fig.update_layout(
    title='Stock live share price',
    yaxis_title='Stock Price($USD)')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list((
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ))
    )
)
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
